# %% [markdown]
# # <h1><b> NLP : TEXT PREPROCESSING PRACTICAL <b></h1>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import re
import pandas as pd

# %%
df = pd.read_csv(r"data\tripadvisor_hotel_reviews.csv")
# pd.set_option("display.max_colwidth", None)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  109 non-null    str
#  1   Rating  109 non-null    int64
# dtypes: int64(1), str(1)
# memory usage: 1.8 KB

# %%
df.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
df["Review"][0]
# Out:
# 'nice hotel expensive parking got good deal stay hotel anniversary, arrived late evening took advice previous reviews did valet parking, check quick easy, little disappointed non-existent view room room clean nice size, bed comfortable woke stiff neck high pillows, not soundproof like heard music room night morning loud bangs doors opening closing hear people talking hallway, maybe just noisy neighbors, aveda bath products nice, did not goldfish stay nice touch taken advantage staying longer, location great walking distance shopping, overall nice experience having pay 40 parking night,  '

# %%
df["review_lowercase"] = df["Review"].str.lower()
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...

# %%
# removing stopwords
en_stopwords = stopwords.words("english")
en_stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
# removing not form the stopwords dictionary
en_stopwords.remove("not")

# %%
df["review_no_stopwords"] = df["review_lowercase"].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))

# %%
df[["review_lowercase", "review_no_stopwords"]].head()
# Out:
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...

# %% [markdown]
#  remove punctuation

# %%
df["reveiw_no_stopwords_no_punct"] = df.apply(lambda x: re.sub(r"[*]", "star", x["review_no_stopwords"]), axis=1)

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
df["reveiw_no_stopwords_no_punct"] = df.apply(lambda x: re.sub(r"[^\w\s]", "", x["reveiw_no_stopwords_no_punct"]), axis=1)

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %% [markdown]
# tokenization

# %%
df["tokenized"] = df.apply(lambda x: word_tokenize(x["reveiw_no_stopwords_no_punct"]), axis=1)
df["tokenized"][0]
# Out:
# ['nice',
#  'hotel',
#  'expensive',
#  'parking',
#  'got',
#  'good',
#  'deal',
#  'stay',
#  'hotel',
#  'anniversary',
#  'arrived',
#  'late',
#  'evening',
#  'took',
#  'advice',
#  'previous',
#  'reviews',
#  'valet',
#  'parking',
#  'check',
#  'quick',
#  'easy',
#  'little',
#  'disappointed',
#  'nonexistent',
#  'view',
#  'room',
#  'room',
#  'clean',
#  'nice',
#  'size',
#  'bed',
#  'comfortable',
#  'woke',
#  'stiff',
#  'neck',
#  'high',
#  'pillows',
#  'not',
#  'soundproof',
#  'like',
#  'heard',
#  'music',
#  'room',
#  'night',
#  'morning',
#  'loud',
#  'bangs',
#  'doors',
#  'opening',
#  'closing',
#  'hear',
#  'people',
#  'talking',
#  'hallway',
#  'maybe',
#  'noisy',
#  'neighbors',
#  'aveda',
#  'bath',
#  'products',
#  'nice',
#  'not',
#  'goldfish',
#  'stay',
#  'nice',
#  'touch',
#  'taken',
#  'advantage',
#  'staying',
#  'longer',
#  'location',
#  'great',
#  'walking',
#  'distance',
#  'shopping',
#  'overall',
#  'nice',
# ...

# %%
ps = PorterStemmer()
df["stemmeized"] = df.apply(lambda x: [ps.stem(word)  for word in x['tokenized']], axis=1)
df[["tokenized", "stemmeized"]].head()
# Out:
#                                            tokenized  \
# 0  [nice, hotel, expensive, parking, got, good, d...
# 1  [ok, nothing, special, charge, diamond, member...
# 2  [nice, rooms, not, 4star, experience, hotel, m...
# 3  [unique, great, stay, wonderful, time, hotel, ...
# 4  [great, stay, great, stay, went, seahawk, game...
#
#                                           stemmeized
# 0  [nice, hotel, expens, park, got, good, deal, s...
# 1  [ok, noth, special, charg, diamond, member, hi...
# 2  [nice, room, not, 4star, experi, hotel, monaco...
# 3  [uniqu, great, stay, wonder, time, hotel, mona...
# 4  [great, stay, great, stay, went, seahawk, game...

# %%
lem = WordNetLemmatizer()
df["lemmentized"] = df.apply(lambda x: [lem.lemmatize(word) for word in x["tokenized"]], axis=1)
df[["tokenized", "stemmeized", "lemmentized"]].head()
# Out:
#                                            tokenized  \
# 0  [nice, hotel, expensive, parking, got, good, d...
# 1  [ok, nothing, special, charge, diamond, member...
# 2  [nice, rooms, not, 4star, experience, hotel, m...
# 3  [unique, great, stay, wonderful, time, hotel, ...
# 4  [great, stay, great, stay, went, seahawk, game...
#
#                                           stemmeized  \
# 0  [nice, hotel, expens, park, got, good, deal, s...
# 1  [ok, noth, special, charg, diamond, member, hi...
# 2  [nice, room, not, 4star, experi, hotel, monaco...
# 3  [uniqu, great, stay, wonder, time, hotel, mona...
# 4  [great, stay, great, stay, went, seahawk, game...
#
#                                          lemmentized
# 0  [nice, hotel, expensive, parking, got, good, d...
# 1  [ok, nothing, special, charge, diamond, member...
# 2  [nice, room, not, 4star, experience, hotel, mo...
# 3  [unique, great, stay, wonderful, time, hotel, ...
# 4  [great, stay, great, stay, went, seahawk, game...

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
token_clean = sum(df["lemmentized"], [])

# %%
unigrams = (pd.Series(nltk.ngrams(token_clean, 1)).value_counts())
print(unigrams)
# Out:
# (hotel,)         292
# (room,)          275
# (great,)         126
# (not,)           122
# (stay,)           95
#                 ...
# (touring,)         1
# (asia,)            1
# (maintained,)      1
# (slipper,)         1
# (connected,)       1
# Name: count, Length: 2589, dtype: int64

# %%
bigrams = (pd.Series(nltk.ngrams(token_clean, 2)).value_counts())
print(bigrams)
# Out:
# (great, location)     24
# (space, needle)       21
# (hotel, monaco)       16
# (staff, friendly)     12
# (pike, place)         12
#                       ..
# (huge, mall)           1
# (mall, hotel)          1
# (hotel, connected)     1
# (connected, good)      1
# (food, raffle)         1
# Name: count, Length: 8263, dtype: int64

# %%
trigrams = (pd.Series(nltk.ngrams(token_clean, 3)).value_counts())
print(trigrams)
# Out:
# (pike, place, market)         8
# (view, space, needle)         5
# (hotel, great, location)      5
# (room, king, bed)             4
# (staff, friendly, helpful)    4
#                              ..
# (connected, good, food)       1
# (good, food, raffle)          1
# (food, raffle, hotel)         1
# (raffle, hotel, right)        1
# (hotel, right, street)        1
# Name: count, Length: 9288, dtype: int64
